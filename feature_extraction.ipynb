# %%
import pandas as pd
import pickle
import numpy as np

# %%
df=pickle.load(open('dataset_2.pkl','rb'))

# %%
#batting_team, bowling_team, city, current score, balls left, wickets left, current run rate, last five overs


df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Australia   0.1     0                0      NaN
# 1           2    Australia    Australia   0.2     0                0      NaN
# 2           2    Australia    Australia   0.3     1                0      NaN
# 3           2    Australia    Australia   0.4     2                0      NaN
# 4           2    Australia    Australia   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Sri Lanka  19.3     1                0  Colombo
# 122       964    Sri Lanka    Sri Lanka  19.4     0                0  Colombo
# 123       964    Sri Lanka    Sri Lanka  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Sri Lanka  19.6     2                0  Colombo
# 125       964    Sri Lanka    Sri Lanka  19.7     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# 1    Melbourne Cricket Ground
# 2    Melbourne Cricket Ground
# 3    Melbourne Cricket Ground
# 4    Melbourne Cricket Ground
# ..                        ...
# 121       R Premadasa Stadium
# 122       R Premadasa Stadium
# 123       R Premadasa Stadium
# 124       R Premadasa Stadium
# 125       R Premadasa Stadium
#
# [71276 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id                0
# batting_team            0
# bowling_team            0
# ball                    0
# runs                    0
# player_dismissed        0
# city                10041
# venue                   0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        3339
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sharjah Cricket Stadium                    1124
# Sydney Cricket Ground                       749
# Harare Sports Club                          620
# Adelaide Oval                               498
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city']=cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Australia   0.1     0                0
# 1           2    Australia    Australia   0.2     0                0
# 2           2    Australia    Australia   0.3     1                0
# 3           2    Australia    Australia   0.4     2                0
# 4           2    Australia    Australia   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Sri Lanka  19.3     1                0
# 122       964    Sri Lanka    Sri Lanka  19.4     0                0
# 123       964    Sri Lanka    Sri Lanka  19.5     0      DM de Silva
# 124       964    Sri Lanka    Sri Lanka  19.6     2                0
# 125       964    Sri Lanka    Sri Lanka  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [71276 rows x 7 columns]

# %%
#minimum 5 matches, so it will be atleast 600 balls
selected_cities=df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df=df[df['city'].isin(selected_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Australia   0.1     0                0
# 1           2    Australia    Australia   0.2     0                0
# 2           2    Australia    Australia   0.3     1                0
# 3           2    Australia    Australia   0.4     2                0
# 4           2    Australia    Australia   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Sri Lanka  19.3     1                0
# 122       964    Sri Lanka    Sri Lanka  19.4     0                0
# 123       964    Sri Lanka    Sri Lanka  19.5     0      DM de Silva
# 124       964    Sri Lanka    Sri Lanka  19.6     2                0
# 125       964    Sri Lanka    Sri Lanka  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [56882 rows x 7 columns]

# %%
df['current_score']=df.groupby('match_id').cumsum()['runs']
# Out:
# <ipython-input-14-d88f26f111a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score']=df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Australia   0.1     0                0
# 1           2    Australia    Australia   0.2     0                0
# 2           2    Australia    Australia   0.3     1                0
# 3           2    Australia    Australia   0.4     2                0
# 4           2    Australia    Australia   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Sri Lanka  19.3     1                0
# 122       964    Sri Lanka    Sri Lanka  19.4     0                0
# 123       964    Sri Lanka    Sri Lanka  19.5     0      DM de Silva
# 124       964    Sri Lanka    Sri Lanka  19.6     2                0
# 125       964    Sri Lanka    Sri Lanka  19.7     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# 3    Melbourne              3
# 4    Melbourne              3
# ..         ...            ...
# 121    Colombo            125
# 122    Colombo            125
# 123    Colombo            125
# 124    Colombo            127
# 125    Colombo            128
#
# [56882 rows x 8 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no']=df['ball'].apply(lambda x:str(x).split(".")[1])
# Out:
# <ipython-input-16-01fb198ea9b4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# <ipython-input-16-01fb198ea9b4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no']=df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Australia   0.1     0                0
# 1           2    Australia    Australia   0.2     0                0
# 2           2    Australia    Australia   0.3     1                0
# 3           2    Australia    Australia   0.4     2                0
# 4           2    Australia    Australia   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Sri Lanka  19.3     1                0
# 122       964    Sri Lanka    Sri Lanka  19.4     0                0
# 123       964    Sri Lanka    Sri Lanka  19.5     0      DM de Silva
# 124       964    Sri Lanka    Sri Lanka  19.6     2                0
# 125       964    Sri Lanka    Sri Lanka  19.7     1                0
#
#           city  current_score over ball_no
# 0    Melbourne              0    0       1
# 1    Melbourne              0    0       2
# 2    Melbourne              1    0       3
# 3    Melbourne              3    0       4
# 4    Melbourne              3    0       5
# ..         ...            ...  ...     ...
# 121    Colombo            125   19       3
# 122    Colombo            125   19       4
# 123    Colombo            125   19       5
# 124    Colombo            127   19       6
# 125    Colombo            128   19       7
#
# [56882 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# <ipython-input-18-e7d17f656852>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Australia   0.1     0                0
# 1           2    Australia    Australia   0.2     0                0
# 2           2    Australia    Australia   0.3     1                0
# 3           2    Australia    Australia   0.4     2                0
# 4           2    Australia    Australia   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Sri Lanka  19.3     1                0
# 122       964    Sri Lanka    Sri Lanka  19.4     0                0
# 123       964    Sri Lanka    Sri Lanka  19.5     0      DM de Silva
# 124       964    Sri Lanka    Sri Lanka  19.6     2                0
# 125       964    Sri Lanka    Sri Lanka  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled
# 0    Melbourne              0    0       1             1
# 1    Melbourne              0    0       2             2
# 2    Melbourne              1    0       3             3
# 3    Melbourne              3    0       4             4
# 4    Melbourne              3    0       5             5
# ..         ...            ...  ...     ...           ...
# 121    Colombo            125   19       3           117
# 122    Colombo            125   19       4           118
# 123    Colombo            125   19       5           119
# 124    Colombo            127   19       6           120
# 125    Colombo            128   19       7           121
#
# [56882 rows x 11 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# <ipython-input-19-7ed065e8960c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# <ipython-input-19-7ed065e8960c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Australia   0.1     0                0
# 1           2    Australia    Australia   0.2     0                0
# 2           2    Australia    Australia   0.3     1                0
# 3           2    Australia    Australia   0.4     2                0
# 4           2    Australia    Australia   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Sri Lanka  19.3     1                0
# 122       964    Sri Lanka    Sri Lanka  19.4     0                0
# 123       964    Sri Lanka    Sri Lanka  19.5     0      DM de Silva
# 124       964    Sri Lanka    Sri Lanka  19.6     2                0
# 125       964    Sri Lanka    Sri Lanka  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
# [56882 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# <ipython-input-20-e0234112d42f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# <ipython-input-20-e0234112d42f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# <ipython-input-20-e0234112d42f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
# <ipython-input-20-e0234112d42f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Australia   0.1     0                 0
# 1           2    Australia    Australia   0.2     0                 0
# 2           2    Australia    Australia   0.3     1                 0
# 3           2    Australia    Australia   0.4     2                 0
# 4           2    Australia    Australia   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Sri Lanka  19.3     1                 8
# 122       964    Sri Lanka    Sri Lanka  19.4     0                 8
# 123       964    Sri Lanka    Sri Lanka  19.5     0                 9
# 124       964    Sri Lanka    Sri Lanka  19.6     2                 9
# 125       964    Sri Lanka    Sri Lanka  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left
# 0              10
# 1              10
# 2              10
# 3              10
# 4              10
# ..            ...
# 121             2
# 122             2
# 123             1
# 124             1
# 125             1
#
# [56882 rows x 13 columns]

# %%
df['crr']=(df['current_score']*6)/df['balls_bowled']
df
# Out:
# <ipython-input-22-7f6b3474487d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr']=(df['current_score']*6)/df['balls_bowled']
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Australia   0.1     0                 0
# 1           2    Australia    Australia   0.2     0                 0
# 2           2    Australia    Australia   0.3     1                 0
# 3           2    Australia    Australia   0.4     2                 0
# 4           2    Australia    Australia   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Sri Lanka  19.3     1                 8
# 122       964    Sri Lanka    Sri Lanka  19.4     0                 8
# 123       964    Sri Lanka    Sri Lanka  19.5     0                 9
# 124       964    Sri Lanka    Sri Lanka  19.6     2                 9
# 125       964    Sri Lanka    Sri Lanka  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr
# 0              10  0.000000
# 1              10  0.000000
# 2              10  2.000000
# 3              10  4.500000
# 4              10  3.600000
# ..            ...       ...
# 121             2  6.410256
# 122             2  6.355932
# 123             1  6.302521
# 124             1  6.350000
# 125             1  6.347107
#
# [56882 rows x 14 columns]

# %%
groups=df.groupby('match_id')

match_ids=df['match_id'].unique()
last_five=[]
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# <ipython-input-24-83d24d575aa4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Australia   0.1     0                 0
# 1           2    Australia    Australia   0.2     0                 0
# 2           2    Australia    Australia   0.3     1                 0
# 3           2    Australia    Australia   0.4     2                 0
# 4           2    Australia    Australia   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Sri Lanka  19.3     1                 8
# 122       964    Sri Lanka    Sri Lanka  19.4     0                 8
# 123       964    Sri Lanka    Sri Lanka  19.5     0                 9
# 124       964    Sri Lanka    Sri Lanka  19.6     2                 9
# 125       964    Sri Lanka    Sri Lanka  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr  last_five
# 0              10  0.000000        NaN
# 1              10  0.000000        NaN
# 2              10  2.000000        NaN
# 3              10  4.500000        NaN
# 4              10  3.600000        NaN
# ..            ...       ...        ...
# 121             2  6.410256       32.0
# 122             2  6.355932       32.0
# 123             1  6.302521       32.0
# 124             1  6.350000       33.0
# 125             1  6.347107       32.0
#
# [56882 rows x 15 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#       batting_team  bowling_team        city  current_score  balls_left  \
# 51358  New Zealand   New Zealand  Wellington             70          69
# 48869  New Zealand  South Africa      Durban             63          79
#
#        wickets_left       crr  last_five  runs_x
# 51358             8  8.235294       28.0     196
# 48869            10  9.219512       55.0     151

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 35272   West Indies     Australia       Colombo            187           2
# 46677      Pakistan  South Africa     Cape Town            159          11
# 50520       England       England       Sharjah             88          42
# 3973       Pakistan      Pakistan    Wellington             71          22
# 5392          India         India  Johannesburg             80          79
# ...             ...           ...           ...            ...         ...
# 52450   Afghanistan   Afghanistan        Nagpur             98          36
# 3477    Afghanistan   West Indies      St Kitts             45          90
# 31494      Pakistan      Pakistan     Abu Dhabi             91          19
# 21067       England   New Zealand  Christchurch             84          60
# 48194  South Africa     Australia     Melbourne             91          17
#
#        wickets_left        crr  last_five
# 35272             3   9.508475       50.0
# 46677             7   8.752294       55.0
# 50520             4   6.769231       24.0
# 3973              3   4.346939       26.0
# 5392              8  11.707317       56.0
# ...             ...        ...        ...
# 52450             6   7.000000       30.0
# 3477              8   9.000000       45.0
# 31494             4   5.405941       32.0
# 21067             6   8.400000       27.0
# 48194             5   5.300971       31.0
#
# [34680 rows x 8 columns]

# %%
from sklearn.compose import ColumnTransformer
import sys
# !{sys.executable} -m pip install xgboost
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error
# Out:
# Requirement already satisfied: xgboost in c:\users\gsstr\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy in c:\users\gsstr\anaconda3\lib\site-packages (from xgboost) (1.20.1)
# Requirement already satisfied: scipy in c:\users\gsstr\anaconda3\lib\site-packages (from xgboost) (1.6.2)

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9782942896059503
# 2.180688731755627

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
selected_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Dubai',
#  'Johannesburg',
#  'Cape Town',
#  'Auckland',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Sharjah',
#  'Lauderhill',
#  'Abu Dhabi',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Lahore',
#  'Nottingham',
#  'Mumbai',
#  'Nagpur',
#  'Southampton',
#  'Chittagong',
#  'Mount Maunganui',
#  'Kolkata',
#  'Dhaka',
#  'Delhi',
#  'Hambantota',
#  'Chandigarh',
#  'Adelaide',
#  'Harare',
#  'Bangalore',
#  'Guyana',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']

# %%
import sklearn
import xgboost

print(sklearn.__version__)
print(xgboost.__version__)
# Out:
# 1.1.3
# 1.7.1
